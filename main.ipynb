# %%
for j in [6]:
    import os
    import numpy as np
    import torch
    import torch.utils.data
    from PIL import Image
    import argparse

    parser = argparse.ArgumentParser("Train code")   
    # when running in jupyterlab
    if os.path.basename(os.path.splitext(sys.argv[0])[0] ) =='ipykernel_launcher':
        parser.add_argument('-f')
    # setting
    parser.add_argument('-m'  ,'--mode'   ,default=-1, type =int  ,metavar='{...}'    ,help="mode index 0: 'edsr','espcn','fsrcnn','lapsrn','bilinear','bicubic'] ")
    parser.add_argument('-b'  ,'--batch'   ,default=-1, type =int  ,metavar='{...}'    ,help="batch size ")
    parser.add_argument('-p'  ,'--pretrained'   ,default=False, type =bool  ,metavar='{...}'    ,help="pre-trained ")
    args = parser.parse_args()

    def get_idle_gpu():
        import GPUtil as gp
        gpus = gp.getGPUs()
        gpus_util = [gpu.memoryUtil for gpu in gpus]

        import numpy as np
        index = np.argmin(gpus_util)
        device = 'cuda:'+str(index)
        return device

    saved  = True
    device = get_idle_gpu()
    device = 'cuda:0'
    num_epochs = 20
    batch_size = args.batch if args.batch != -1 else 4
    pretrained = True
    pretrained = args.pretrained
    mode_names = ['edsr','espcn','fsrcnn','lapsrn','bilinear','bicubic','nearest']
    mode_index = args.mode if args.mode != -1 else 1
    mode_index = j
    mode_name = 'ensemble-'+ mode_names[mode_index] if mode_index in range(0,4) else mode_names[mode_index]
    classes = ['Nothing','Pedestrian']    

    print(f'{mode_name} is started on the {device}')
    print(f'batch {batch_size}')

    class PennFudanDataset(torch.utils.data.Dataset):
        def __init__(self, root, transforms=None):
            self.root = root
            self.transforms = transforms
            # load all image files, sorting them to
            # ensure that they are aligned
            self.imgs = list(sorted(os.listdir(os.path.join(root, "PNGImages"))))
            self.masks = list(sorted(os.listdir(os.path.join(root, "PedMasks"))))

        def __getitem__(self, idx):
            # load images ad masks
            img_path = os.path.join(self.root, "PNGImages", self.imgs[idx])
            mask_path = os.path.join(self.root, "PedMasks", self.masks[idx])
            img = Image.open(img_path).convert("RGB")
            # note that we haven't converted the mask to RGB,
            # because each color corresponds to a different instance
            # with 0 being background
            mask = Image.open(mask_path)

            mask = np.array(mask)
            # instances are encoded as different colors
            obj_ids = np.unique(mask)
            # first id is the background, so remove it
            obj_ids = obj_ids[1:]

            # split the color-encoded mask into a set
            # of binary masks
            masks = mask == obj_ids[:, None, None]

            # get bounding box coordinates for each mask
            num_objs = len(obj_ids)
            boxes = []
            for i in range(num_objs):
                pos = np.where(masks[i])
                xmin = np.min(pos[1])
                xmax = np.max(pos[1])
                ymin = np.min(pos[0])
                ymax = np.max(pos[0])
                boxes.append([xmin, ymin, xmax, ymax])

            boxes = torch.as_tensor(boxes, dtype=torch.float32)
            # there is only one class
            labels = torch.ones((num_objs,), dtype=torch.int64)
            masks = torch.as_tensor(masks, dtype=torch.uint8)

            image_id = torch.tensor([idx])
            area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
            # suppose all instances are not crowd
            iscrowd = torch.zeros((num_objs,), dtype=torch.int64)

            target = {}
            target["boxes"]    = boxes
            target["labels"]   = labels
            target["masks"]    = masks
            target["image_id"] = image_id
            target["area"]     = area
            target["iscrowd"]  = iscrowd

            if self.transforms is not None:
                img, target = self.transforms(img, target)

            return img, target

        def __len__(self):
            return len(self.imgs)

    import torchvision
    from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
    from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor
    from rcnn_transfrom import InterpolationTransform as it

    def get_instance_segmentation_model(num_classes,pretrained=True,mode_name='ensemble-edsr'):
        # load an instance segmentation model pre-trained on COCO
        model = torchvision.models.detection.maskrcnn_resnet50_fpn(pretrained)

        # get the number of input features for the classifier
        in_features = model.roi_heads.box_predictor.cls_score.in_features
        # replace the pre-trained head with a new one
        model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

        # now get the number of input features for the mask classifier
        in_features_mask = model.roi_heads.mask_predictor.conv5_mask.in_channels
        hidden_layer = 256
        # and replace the mask predictor with a new one
        model.roi_heads.mask_predictor = MaskRCNNPredictor(in_features_mask,
                                                           hidden_layer,
                                                           num_classes)

        model.transform = it(min_size=(800,), max_size=1333,image_mean=[0.485, 0.456, 0.406],image_std=[0.229, 0.224, 0.225],mode=mode_name)
        return model

    from engine import train_one_epoch, evaluate
    import utils
    import transforms as T


    def get_transform(train):
        transforms = []
        # converts the image, a PIL image, into a PyTorch Tensor
        transforms.append(T.ToTensor())
        if train:
            # during training, randomly flip the training images
            # and ground-truth for data augmentation
            transforms.append(T.RandomHorizontalFlip(0.5))
        return T.Compose(transforms)

    dataset      = PennFudanDataset('PennFudanPed', get_transform(train=True))
    dataset_test = PennFudanDataset('PennFudanPed', get_transform(train=False))

    torch.manual_seed(1)
    indices = torch.randperm(len(dataset)).tolist()
    dataset = torch.utils.data.Subset(dataset, indices[:-50])
    dataset_test = torch.utils.data.Subset(dataset_test, indices[-50:])

    data_loader = torch.utils.data.DataLoader(
        dataset, batch_size=batch_size, shuffle=True, num_workers=4,
        collate_fn=utils.collate_fn)

    data_loader_test = torch.utils.data.DataLoader(
        dataset_test, batch_size=1, shuffle=False, num_workers=4,
        collate_fn=utils.collate_fn)


    num_classes = 2


    model = get_instance_segmentation_model(num_classes,pretrained=pretrained,mode_name=mode_name)


    model.to(device)


    params = [p for p in model.parameters() if p.requires_grad]
    optimizer = torch.optim.SGD(params, lr=0.005,
                                momentum=0.9, weight_decay=0.0005)


    lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                                   step_size=3,
                                                   gamma=0.1)


    from tqdm import notebook as nb
    import tqdm
    evaluators = []
    for epoch in range(num_epochs):


        train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=10)

        lr_scheduler.step()
        # evaluate on the test dataset
        # device = 'cuda:1'
        # model.to(device)
        evaluators.append( evaluate(model, data_loader_test, device=device) )

    if saved:
        if pretrained :
            torch.save({'state_dict':model.state_dict(),
                'evaluators':evaluators
                },f'./model/pf_{batch_size}_{mode_name}.pth')
        else:
            torch.save({'state_dict':model.state_dict(),
                'evaluators':evaluators
                },f'./model/pf_{batch_size}_{mode_name}_{pretrained}.pth')
    else:
        pass
# Out:
# nearest is started on the cuda:0
# batch 4
# Epoch: [0]  [ 0/30]  eta: 0:00:22  lr: 0.000177  loss: 3.8360 (3.8360)  loss_classifier: 0.6573 (0.6573)  loss_box_reg: 0.0141 (0.0141)  loss_mask: 2.4488 (2.4488)  loss_objectness: 0.6950 (0.6950)  loss_rpn_box_reg: 0.0207 (0.0207)  time: 0.7404  data: 0.2710  max mem: 6332
# Epoch: [0]  [10/30]  eta: 0:00:09  lr: 0.001900  loss: 2.6108 (2.7871)  loss_classifier: 0.6119 (0.5939)  loss_box_reg: 0.0072 (0.0082)  loss_mask: 1.2847 (1.4774)  loss_objectness: 0.6905 (0.6899)  loss_rpn_box_reg: 0.0161 (0.0177)  time: 0.4981  data: 0.0307  max mem: 6332
# Epoch: [0]  [20/30]  eta: 0:00:04  lr: 0.003622  loss: 1.8850 (2.2242)  loss_classifier: 0.4617 (0.4021)  loss_box_reg: 0.0127 (0.0359)  loss_mask: 0.7599 (1.1193)  loss_objectness: 0.6814 (0.6475)  loss_rpn_box_reg: 0.0177 (0.0195)  time: 0.4799  data: 0.0194  max mem: 6332
# Epoch: [0]  [29/30]  eta: 0:00:00  lr: 0.005000  loss: 1.6803 (1.9191)  loss_classifier: 0.1590 (0.3128)  loss_box_reg: 0.0467 (0.0577)  loss_mask: 0.7261 (0.9938)  loss_objectness: 0.6410 (0.5343)  loss_rpn_box_reg: 0.0177 (0.0205)  time: 0.4677  data: 0.0155  max mem: 6332
# Epoch: [0] Total time: 0:00:14 (0.4697 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:09  model_time: 0.0621 (0.0621)  evaluator_time: 0.0063 (0.0063)  time: 0.1811  data: 0.1118  max mem: 6332
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0592 (0.0611)  evaluator_time: 0.0096 (0.0137)  time: 0.0804  data: 0.0046  max mem: 6332
# Test: Total time: 0:00:04 (0.0814 s / it)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.065
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.016
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.103
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.208
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.223
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.009
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.045
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.049
# Epoch: [1]  [ 0/30]  eta: 0:00:24  lr: 0.005000  loss: 1.2027 (1.2027)  loss_classifier: 0.1996 (0.1996)  loss_box_reg: 0.2211 (0.2211)  loss_mask: 0.6277 (0.6277)  loss_objectness: 0.1211 (0.1211)  loss_rpn_box_reg: 0.0333 (0.0333)  time: 0.8102  data: 0.3070  max mem: 6332
# Epoch: [1]  [10/30]  eta: 0:00:10  lr: 0.005000  loss: 0.9468 (1.0038)  loss_classifier: 0.1106 (0.1135)  loss_box_reg: 0.1072 (0.1177)  loss_mask: 0.6311 (0.6833)  loss_objectness: 0.0758 (0.0716)  loss_rpn_box_reg: 0.0190 (0.0178)  time: 0.5082  data: 0.0322  max mem: 6332
# Epoch: [1]  [20/30]  eta: 0:00:04  lr: 0.005000  loss: 0.9468 (0.9815)  loss_classifier: 0.1140 (0.1154)  loss_box_reg: 0.1093 (0.1164)  loss_mask: 0.6259 (0.6550)  loss_objectness: 0.0736 (0.0750)  loss_rpn_box_reg: 0.0190 (0.0198)  time: 0.4827  data: 0.0202  max mem: 6332
# Epoch: [1]  [29/30]  eta: 0:00:00  lr: 0.005000  loss: 0.9368 (0.9651)  loss_classifier: 0.1074 (0.1114)  loss_box_reg: 0.1087 (0.1137)  loss_mask: 0.6190 (0.6485)  loss_objectness: 0.0659 (0.0715)  loss_rpn_box_reg: 0.0171 (0.0200)  time: 0.4951  data: 0.0162  max mem: 6332
# Epoch: [1] Total time: 0:00:14 (0.4969 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:11  model_time: 0.1043 (0.1043)  evaluator_time: 0.0255 (0.0255)  time: 0.2399  data: 0.1090  max mem: 6332
# Test:  [49/50]  eta: 0:00:00  model_time: 0.1008 (0.0997)  evaluator_time: 0.0347 (0.0373)  time: 0.1434  data: 0.0042  max mem: 6332
# Test: Total time: 0:00:07 (0.1443 s / it)
# Accumulating evaluation results...
# DONE (t=0.05s).
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.037
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.058
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.271
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.025
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.288
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.039
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.025
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.040
# Epoch: [2]  [ 0/30]  eta: 0:00:21  lr: 0.005000  loss: 0.8411 (0.8411)  loss_classifier: 0.0967 (0.0967)  loss_box_reg: 0.0667 (0.0667)  loss_mask: 0.5694 (0.5694)  loss_objectness: 0.0866 (0.0866)  loss_rpn_box_reg: 0.0217 (0.0217)  time: 0.7042  data: 0.2511  max mem: 6332
# Epoch: [2]  [10/30]  eta: 0:00:09  lr: 0.005000  loss: 0.8818 (0.8938)  loss_classifier: 0.0975 (0.1095)  loss_box_reg: 0.1048 (0.1107)  loss_mask: 0.5798 (0.5819)  loss_objectness: 0.0596 (0.0697)  loss_rpn_box_reg: 0.0217 (0.0220)  time: 0.4885  data: 0.0283  max mem: 6332
s / it)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.115
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.382
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.123
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.074
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.298
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.360
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.385
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.107
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.408
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.079
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.245
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.299
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.062
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.316
# Epoch: [6]  [ 0/30]  eta: 0:00:22  lr: 0.000050  loss: 0.7694 (0.7694)  loss_classifier: 0.1343 (0.1343)  loss_box_reg: 0.1434 (0.1434)  loss_mask: 0.4020 (0.4020)  loss_objectness: 0.0703 (0.0703)  loss_rpn_box_reg: 0.0195 (0.0195)  time: 0.7342  data: 0.2842  max mem: 6332
# Epoch: [6]  [10/30]  eta: 0:00:10  lr: 0.000050  loss: 0.6871 (0.6972)  loss_classifier: 0.0935 (0.0949)  loss_box_reg: 0.1434 (0.1366)  loss_mask: 0.4161 (0.4115)  loss_objectness: 0.0349 (0.0380)  loss_rpn_box_reg: 0.0164 (0.0163)  time: 0.5168  data: 0.0302  max mem: 6332
# Epoch: [6]  [20/30]  eta: 0:00:05  lr: 0.000050  loss: 0.6921 (0.7056)  loss_classifier: 0.0965 (0.0975)  loss_box_reg: 0.1434 (0.1413)  loss_mask: 0.4040 (0.4086)  loss_objectness: 0.0370 (0.0403)  loss_rpn_box_reg: 0.0177 (0.0179)  time: 0.5333  data: 0.0191  max mem: 6332
# Epoch: [6]  [29/30]  eta: 0:00:00  lr: 0.000050  loss: 0.6921 (0.7060)  loss_classifier: 0.0949 (0.0946)  loss_box_reg: 0.1322 (0.1360)  loss_mask: 0.4040 (0.4148)  loss_objectness: 0.0370 (0.0430)  loss_rpn_box_reg: 0.0174 (0.0177)  time: 0.5310  data: 0.0154  max mem: 6332
# Epoch: [6] Total time: 0:00:15 (0.5326 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:10  model_time: 0.0824 (0.0824)  evaluator_time: 0.0109 (0.0109)  time: 0.2032  data: 0.1088  max mem: 6332
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0743 (0.0738)  evaluator_time: 0.0166 (0.0203)  time: 0.0999  data: 0.0043  max mem: 6332
# Test: Total time: 0:00:05 (0.1008 s / it)
# Accumulating evaluation results...
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.114
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.381
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.004
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.123
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.074
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.301
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.366
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.391
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.110
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.415
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.132
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.081
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.251
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.303
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.062
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.320
# Epoch: [7]  [ 0/30]  eta: 0:00:21  lr: 0.000050  loss: 0.6576 (0.6576)  loss_classifier: 0.0979 (0.0979)  loss_box_reg: 0.1356 (0.1356)  loss_mask: 0.3582 (0.3582)  loss_objectness: 0.0438 (0.0438)  loss_rpn_box_reg: 0.0221 (0.0221)  time: 0.7094  data: 0.2894  max mem: 6332
# Epoch: [7]  [10/30]  eta: 0:00:10  lr: 0.000050  loss: 0.6661 (0.6764)  loss_classifier: 0.0850 (0.0867)  loss_box_reg: 0.1356 (0.1354)  loss_mask: 0.3883 (0.3968)  loss_objectness: 0.0363 (0.0384)  loss_rpn_box_reg: 0.0194 (0.0191)  time: 0.5176  data: 0.0307  max mem: 6332
# Epoch: [7]  [20/30]  eta: 0:00:05  lr: 0.000050  loss: 0.6675 (0.6919)  loss_classifier: 0.0862 (0.0917)  loss_box_reg: 0.1326 (0.1356)  loss_mask: 0.4016 (0.4061)  loss_objectness: 0.0394 (0.0407)  loss_rpn_box_reg: 0.0172 (0.0178)  time: 0.5158  data: 0.0194  max mem: 6332
# Epoch: [7]  [29/30]  eta: 0:00:00  lr: 0.000050  loss: 0.7110 (0.7068)  loss_classifier: 0.0945 (0.0951)  loss_box_reg: 0.1334 (0.1364)  loss_mask: 0.4052 (0.4127)  loss_objectness: 0.0368 (0.0443)  loss_rpn_box_reg: 0.0172 (0.0183)  time: 0.5226  data: 0.0157  max mem: 6332
# Epoch: [7] Total time: 0:00:15 (0.5245 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:09  model_time: 0.
# Epoch: [9]  [20/30]  eta: 0:00:05  lr: 0.000005  loss: 0.7228 (0.7124)  loss_classifier: 0.0940 (0.0974)  loss_box_reg: 0.1436 (0.1377)  loss_mask: 0.4024 (0.4147)  loss_objectness: 0.0372 (0.0439)  loss_rpn_box_reg: 0.0194 (0.0188)  time: 0.5473  data: 0.0173  max mem: 6332
# Epoch: [9]  [29/30]  eta: 0:00:00  lr: 0.000005  loss: 0.6896 (0.6936)  loss_classifier: 0.0913 (0.0949)  loss_box_reg: 0.1400 (0.1339)  loss_mask: 0.3861 (0.4036)  loss_objectness: 0.0372 (0.0429)  loss_rpn_box_reg: 0.0187 (0.0183)  time: 0.5343  data: 0.0143  max mem: 6332
# Epoch: [9] Total time: 0:00:16 (0.5359 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:11  model_time: 0.0894 (0.0894)  evaluator_time: 0.0223 (0.0223)  time: 0.2333  data: 0.1203  max mem: 6332
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0726 (0.0745)  evaluator_time: 0.0172 (0.0203)  time: 0.1009  data: 0.0046  max mem: 6332
# Test: Total time: 0:00:05 (0.1019 s / it)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.117
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.381
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.037
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.125
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.079
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.301
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.352
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.377
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.115
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.419
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.140
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.082
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.252
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.302
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.062
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.319
# Epoch: [10]  [ 0/30]  eta: 0:00:27  lr: 0.000005  loss: 0.6606 (0.6606)  loss_classifier: 0.0835 (0.0835)  loss_box_reg: 0.1155 (0.1155)  loss_mask: 0.4140 (0.4140)  loss_objectness: 0.0329 (0.0329)  loss_rpn_box_reg: 0.0147 (0.0147)  time: 0.9152  data: 0.2447  max mem: 6332
# Epoch: [10]  [10/30]  eta: 0:00:10  lr: 0.000005  loss: 0.7126 (0.7231)  loss_classifier: 0.0992 (0.0985)  loss_box_reg: 0.1538 (0.1506)  loss_mask: 0.4140 (0.4147)  loss_objectness: 0.0355 (0.0398)  loss_rpn_box_reg: 0.0204 (0.0194)  time: 0.5403  data: 0.0288  max mem: 6332
# Epoch: [10]  [20/30]  eta: 0:00:05  lr: 0.000005  loss: 0.7295 (0.7215)  loss_classifier: 0.0895 (0.1005)  loss_box_reg: 0.1493 (0.1421)  loss_mask: 0.4076 (0.4166)  loss_objectness: 0.0355 (0.0446)  loss_rpn_box_reg: 0.0185 (0.0178)  time: 0.5277  data: 0.0187  max mem: 6332
# Epoch: [10]  [29/30]  eta: 0:00:00  lr: 0.000005  loss: 0.6843 (0.6981)  loss_classifier: 0.0857 (0.0956)  loss_box_reg: 0.1297 (0.1383)  loss_mask: 0.3997 (0.4032)  loss_objectness: 0.0355 (0.0432)  loss_rpn_box_reg: 0.0171 (0.0179)  time: 0.5383  data: 0.0151  max mem: 6332
# Epoch: [10] Total time: 0:00:16 (0.5403 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:10  model_time: 0.0753 (0.0753)  evaluator_time: 0.0118 (0.0118)  time: 0.2101  data: 0.1220  max mem: 6332
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0710 (0.0735)  evaluator_time: 0.0165 (0.0203)  time: 0.0999  data: 0.0045  max mem: 6332
# Test: Total time: 0:00:05 (0.1011 s / it)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.118
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.389
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.036
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.126
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.077
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.303
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.352
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.377
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.119
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.426
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.144
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.082
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.255
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.303
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.062
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.321
# Epoch: [11]  [ 0/30]  eta: 0:00:24  lr: 0.000005  loss: 0.7585 (0.7585)  loss_classifier: 0.1054 (0.1054)  loss_box_reg: 0.1291 (0.1291)  loss_mask: 0.4632 (0.4632)  loss_objectness: 0.0424 (0.0424)  loss_rpn_box_reg: 0.0184 (0.0184)  time: 0.8183  data: 0.3023  max mem: 6332
# Epoch: [11]  [10/30]  eta: 0:00:10  lr: 0.000005  loss: 0.6689 (0.7113)  loss_classifier: 0.0829 (0.0963)  loss_box_reg: 0.1243 (0.1266)  loss_mask: 0.4094 (0.4208)  loss_objectness: 0.0368 (0.0502)  loss_rpn_box_reg: 0.0148 (0.0175)  time: 0.5306  data: 0.0323  max mem: 6332
# Epoch: [11]  [20/30]  eta: 0:00:05  lr: 0.000005  loss: 0.6805 (0.7107)  loss_classifier: 0.0918 (0.0987)  loss_box_reg: 0.1313 (0.1371)  loss_mask: 0.4056 (0.4115)  loss_objectness: 0.0368 (0.0458)  loss_rpn_box_reg: 0.0148 (0.0176)  time: 0.5361  data: 0.0203  max mem: 6332
# Epoch: [11]  [29/30]  eta: 0:00:00  lr: 0.000005  loss: 0.6702 (0.6980)  loss_classifier: 0.0916 (0.0962)  loss_box_reg: 0.1291 (0.1370)  loss_mask: 0.4040 (0.4046)  loss_objectness: 0.0367 (0.0424)  loss_rpn_box_reg: 0.0156 (0.0177)  time: 0.5274  data: 0.0162  max mem: 6332
# Epoch: [11] Total time: 0:00:15 (0.5292 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:10  model_time: 0.0755 (0.0755)  evaluator_time: 0.0110 (0.0110)  time: 0.2014  data: 0.1138  max mem: 6332
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0707 (0.0732)  evaluator_time: 0.0163 (0.0204)  time: 0.0994  data: 0.0044  max mem: 6332
# Test: Total time: 0:00:05 (0.1005 s / it)
# Accumulating evaluation results...
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.118
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.390
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.037
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.126
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.077
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.303
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.352
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.377
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.119
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.427
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.144
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.082
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.255
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.062
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.322
# Epoch: [12]  [ 0/30]  eta: 0:00:22  lr: 0.000001  loss: 0.5802 (0.5802)  loss_classifier: 0.0571 (0.0571)  loss_box_reg: 0.0769 (0.0769)  loss_mask: 0.4108 (0.4108)  loss_objectness: 0.0233 (0.0233)  loss_rpn_box_reg: 0.0120 (0.0120)  time: 0.7565  data: 0.2658  max mem: 6332
# Epoch: [12]  [10/30]  eta: 0:00:10  lr: 0.000001  loss: 0.7036 (0.6855)  loss_classifier: 0.1012 (0.0917)  loss_box_reg: 0.1508 (0.1341)  loss_mask: 0.3990 (0.3972)  loss_objectness: 0.0398 (0.0423)  loss_rpn_box_reg: 0.0215 (0.0202)  time: 0.5233  data: 0.0302  max mem: 6332
# Epoch: [12]  [20/30]  eta: 0:00:05  lr: 0.000001  loss: 0.7032 (0.7021)  loss_classifier: 0.0970 (0.0965)  loss_box_reg: 0.1487 (0.1367)  loss_mask: 0.3990 (0.4035)  loss_objectness: 0.0393 (0.0463)  loss_rpn_box_reg: 0.0215 (0.0191)  time: 0.5206  data: 0.0191  max mem: 6332
# Epoch: [12]  [29/30]  eta: 0:00:00  lr: 0.000001  loss: 0.7016 (0.6993)  loss_classifier: 0.0931 (0.0967)  loss_box_reg: 0.1408 (0.1361)  loss_mask: 0.3990 (0.4055)  loss_objectness: 0.0354 (0.0431)  loss_rpn_box_reg: 0.0173 (0.0180)  time: 0.5283  data: 0.0156  max mem: 6332
# Epoch: [12] Total time: 0:00:15 (0.5306 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:10  model_time: 0.0792 (0.0792)  evaluator_time: 0.0118 (0.0118)  time: 0.2005  data: 0.1083  max mem: 6332
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0710 (0.0737)  evaluator_time: 0.0168 (0.0205)  time: 0.0999  data: 0.0043  max mem: 6332
# Test: Total time: 0:00:05 (0.1009 s / it)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.118
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.390
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.037
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.126
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.077
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.353
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.377
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.118
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.426
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.082
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.255
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.303
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.062
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.320
# Epoch: [13]  [ 0/30]  eta: 0:00:23  lr: 0.000001  loss: 0.6499 (0.6499)  loss_classifier: 0.0828 (0.0828)  loss_box_reg: 0.1248 (0.1248)  loss_mask: 0.3930 (0.3930)  loss_objectness: 0.0335 (0.0335)  loss_rpn_box_reg: 0.0157 (0.0157)  time: 0.7928  data: 0.2972  max mem: 6332
# Epoch: [13]  [10/30]  eta: 0:00:10  lr: 0.000001  loss: 0.6945 (0.6973)  loss_classifier: 0.0984 (0.0916)  loss_box_reg: 0.1476 (0.1389)  loss_mask: 0.3930 (0.4108)  loss_objectness: 0.0362 (0.0379)  loss_rpn_box_reg: 0.0170 (0.0181)  time: 0.5195  data: 0.0315  max mem: 6332
# Epoch: [13]  [20/30]  eta: 0:00:05  lr: 0.000001  loss: 0.6891 (0.6912)  loss_classifier: 0.0984 (0.0940)  loss_box_reg: 0.1476 (0.1387)  loss_mask: 0.3930 (0.4012)  loss_objectness: 0.0369 (0.0397)  loss_rpn_box_reg: 0.0170 (0.0176)  time: 0.5179  data: 0.0201  max mem: 6332
# Epoch: [13]  [29/30]  eta: 0:00:00  lr: 0.000001  loss: 0.6878 (0.6972)  loss_classifier: 0.0984 (0.0954)  loss_box_reg: 0.1308 (0.1368)  loss_mask: 0.3935 (0.4041)  loss_objectness: 0.0366 (0.0429)  loss_rpn_box_reg: 0.0170 (0.0180)  time: 0.5290  data: 0.0162  max mem: 6332
# Epoch: [13] Total time: 0:00:15 (0.5306 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:09  model_time: 0.0750 (0.0750)  evaluator_time: 0.0112 (0.0112)  time: 0.1999  data: 0.1124  max mem: 6332
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0717 (0.0742)  evaluator_time: 0.0167 (0.0206)  time: 0.1007  data: 0.0044  max mem: 6332
# Test: Total time: 0:00:05 (0.1017 s / it)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.118
# ...
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.126
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.077
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.353
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.377
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.119
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.427
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.144
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.082
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.255
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.062
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.322
# Epoch: [16]  [ 0/30]  eta: 0:00:22  lr: 0.000000  loss: 0.5978 (0.5978)  loss_classifier: 0.0767 (0.0767)  loss_box_reg: 0.0909 (0.0909)  loss_mask: 0.3365 (0.3365)  loss_objectness: 0.0741 (0.0741)  loss_rpn_box_reg: 0.0195 (0.0195)  time: 0.7507  data: 0.2284  max mem: 6332
# Epoch: [16]  [10/30]  eta: 0:00:10  lr: 0.000000  loss: 0.6735 (0.6854)  loss_classifier: 0.1000 (0.0913)  loss_box_reg: 0.1247 (0.1352)  loss_mask: 0.3944 (0.4015)  loss_objectness: 0.0375 (0.0407)  loss_rpn_box_reg: 0.0165 (0.0167)  time: 0.5093  data: 0.0273  max mem: 6332
# Epoch: [16]  [20/30]  eta: 0:00:05  lr: 0.000000  loss: 0.6681 (0.6932)  loss_classifier: 0.0877 (0.0940)  loss_box_reg: 0.1247 (0.1301)  loss_mask: 0.4000 (0.4065)  loss_objectness: 0.0375 (0.0452)  loss_rpn_box_reg: 0.0165 (0.0173)  time: 0.5128  data: 0.0176  max mem: 6332
# Epoch: [16]  [29/30]  eta: 0:00:00  lr: 0.000000  loss: 0.6681 (0.6954)  loss_classifier: 0.0912 (0.0950)  loss_box_reg: 0.1368 (0.1360)  loss_mask: 0.3944 (0.4041)  loss_objectness: 0.0357 (0.0424)  loss_rpn_box_reg: 0.0168 (0.0180)  time: 0.5247  data: 0.0145  max mem: 6332
# Epoch: [16] Total time: 0:00:15 (0.5264 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:10  model_time: 0.0758 (0.0758)  evaluator_time: 0.0109 (0.0109)  time: 0.2096  data: 0.1219  max mem: 6332
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0710 (0.0736)  evaluator_time: 0.0166 (0.0202)  time: 0.0997  data: 0.0045  max mem: 6332
# Test: Total time: 0:00:05 (0.1007 s / it)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.118
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.391
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.037
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.126
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.077
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.353
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.377
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.119
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.427
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.144
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.082
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.255
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.062
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.322
# Epoch: [17]  [ 0/30]  eta: 0:00:20  lr: 0.000000  loss: 0.7287 (0.7287)  loss_classifier: 0.0815 (0.0815)  loss_box_reg: 0.1322 (0.1322)  loss_mask: 0.4661 (0.4661)  loss_objectness: 0.0329 (0.0329)  loss_rpn_box_reg: 0.0159 (0.0159)  time: 0.6790  data: 0.2521  max mem: 6332
# Epoch: [17]  [10/30]  eta: 0:00:10  lr: 0.000000  loss: 0.7287 (0.6880)  loss_classifier: 0.0815 (0.0833)  loss_box_reg: 0.1329 (0.1301)  loss_mask: 0.4307 (0.4206)  loss_objectness: 0.0361 (0.0356)  loss_rpn_box_reg: 0.0196 (0.0184)  time: 0.5051  data: 0.0281  max mem: 6332
# Epoch: [17]  [20/30]  eta: 0:00:05  lr: 0.000000  loss: 0.6848 (0.6917)  loss_classifier: 0.0861 (0.0898)  loss_box_reg: 0.1374 (0.1366)  loss_mask: 0.4012 (0.4072)  loss_objectness: 0.0393 (0.0388)  loss_rpn_box_reg: 0.0196 (0.0193)  time: 0.5366  data: 0.0182  max mem: 6332
# Epoch: [17]  [29/30]  eta: 0:00:00  lr: 0.000000  loss: 0.6848 (0.6983)  loss_classifier: 0.0897 (0.0948)  loss_box_reg: 0.1374 (0.1378)  loss_mask: 0.4012 (0.4044)  loss_objectness: 0.0361 (0.0427)  loss_rpn_box_reg: 0.0185 (0.0185)  time: 0.5441  data: 0.0149  max mem: 6332
# Epoch: [17] Total time: 0:00:16 (0.5458 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:10  model_time: 0.0757 (0.0757)  evaluator_time: 0.0115 (0.0115)  time: 0.2025  data: 0.1143  max mem: 6332
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0718 (0.0740)  evaluator_time: 0.0166 (0.0206)  time: 0.1004  data: 0.0044  max mem: 6332
# Test: Total time: 0:00:05 (0.1014 s / it)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.118
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.390
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.037
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.126
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.077
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.353
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.377
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.119
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.427
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.144
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.082
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.255
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.062
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.322
# Epoch: [18]  [ 0/30]  eta: 0:00:19  lr: 0.000000  loss: 0.6544 (0.6544)  loss_classifier: 0.0804 (0.0804)  loss_box_reg: 0.1177 (0.1177)  loss_mask: 0.4149 (0.4149)  loss_objectness: 0.0270 (0.0270)  loss_rpn_box_reg: 0.0145 (0.0145)  time: 0.6412  data: 0.2773  max mem: 6332
# Epoch: [18]  [10/30]  eta: 0:00:10  lr: 0.000000  loss: 0.7044 (0.7191)  loss_classifier: 0.0875 (0.0989)  loss_box_reg: 0.1251 (0.1387)  loss_mask: 0.4211 (0.4083)  loss_objectness: 0.0360 (0.0520)  loss_rpn_box_reg: 0.0205 (0.0213)  time: 0.5014  data: 0.0311  max mem: 6332
# Epoch: [18]  [20/30]  eta: 0:00:05  lr: 0.000000  loss: 0.6930 (0.7045)  loss_classifier: 0.0862 (0.0946)  loss_box_reg: 0.1278 (0.1401)  loss_mask: 0.4132 (0.4049)  loss_objectness: 0.0357 (0.0447)  loss_rpn_box_reg: 0.0191 (0.0201)  time: 0.5159  data: 0.0198  max mem: 6332
# Epoch: [18]  [29/30]  eta: 0:00:00  lr: 0.000000  loss: 0.6696 (0.6911)  loss_classifier: 0.0866 (0.0927)  loss_box_reg: 0.1231 (0.1335)  loss_mask: 0.4108 (0.4046)  loss_objectness: 0.0350 (0.0422)  loss_rpn_box_reg: 0.0171 (0.0180)  time: 0.5350  data: 0.0161  max mem: 6332
# Epoch: [18] Total time: 0:00:16 (0.5367 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:10  model_time: 0.0877 (0.0877)  evaluator_time: 0.0218 (0.0218)  time: 0.2185  data: 0.1079  max mem: 6332
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0709 (0.0739)  evaluator_time: 0.0168 (0.0206)  time: 0.1002  data: 0.0043  max mem: 6332
# Test: Total time: 0:00:05 (0.1012 s / it)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.118
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.390
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.037
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.126
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.077
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.353
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.377
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.119
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.427
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.144
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.082
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.255
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.062
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.322
# Epoch: [19]  [ 0/30]  eta: 0:00:21  lr: 0.000000  loss: 0.4560 (0.4560)  loss_classifier: 0.0425 (0.0425)  loss_box_reg: 0.0486 (0.0486)  loss_mask: 0.3425 (0.3425)  loss_objectness: 0.0194 (0.0194)  loss_rpn_box_reg: 0.0029 (0.0029)  time: 0.7119  data: 0.2647  max mem: 6332
# Epoch: [19]  [10/30]  eta: 0:00:10  lr: 0.000000  loss: 0.6615 (0.6476)  loss_classifier: 0.0829 (0.0791)  loss_box_reg: 0.1320 (0.1223)  loss_mask: 0.3770 (0.3959)  loss_objectness: 0.0353 (0.0337)  loss_rpn_box_reg: 0.0176 (0.0167)  time: 0.5101  data: 0.0294  max mem: 6332
# Epoch: [19]  [20/30]  eta: 0:00:05  lr: 0.000000  loss: 0.6944 (0.7013)  loss_classifier: 0.0903 (0.0964)  loss_box_reg: 0.1365 (0.1395)  loss_mask: 0.4083 (0.4005)  loss_objectness: 0.0383 (0.0454)  loss_rpn_box_reg: 0.0208 (0.0194)  time: 0.5311  data: 0.0187  max mem: 6332
# Epoch: [19]  [29/30]  eta: 0:00:00  lr: 0.000000  loss: 0.6944 (0.6936)  loss_classifier: 0.0903 (0.0955)  loss_box_reg: 0.1348 (0.1366)  loss_mask: 0.3908 (0.4008)  loss_objectness: 0.0368 (0.0427)  loss_rpn_box_reg: 0.0176 (0.0180)  time: 0.5333  data: 0.0151  max mem: 6332
# Epoch: [19] Total time: 0:00:16 (0.5350 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:09  model_time: 0.0753 (0.0753)  evaluator_time: 0.0112 (0.0112)  time: 0.1951  data: 0.1074  max mem: 6332
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0708 (0.0739)  evaluator_time: 0.0164 (0.0212)  time: 0.1008  data: 0.0043  max mem: 6332
# Test: Total time: 0:00:05 (0.1018 s / it)
# Accumulating evaluation results...
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.118
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.391
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.037
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.126
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.077
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.353
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.377
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.119
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.427
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.144
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.082
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.255
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.062
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.322

# %%
import requests as rq
from PIL import Image
import io
url = 'https://images.7news.com.au/publication/C-736288/fc3832987f18c7e8132938d70bdd71c8f5d17673-16x9-x0y285w5472h3078.jpg?imwidth=650&impolicy=sevennews_v2'
img = Image.open(io.BytesIO(rq.get(url).content ))

from torchvision.transforms import functional as vfc 
imt  = vfc.pil_to_tensor(img)

# %%
imtf = vfc.to_tensor(img)
